# %%
import datatable as dt
from datatable import f,by,mean,median
import pandas as pd
from itertools import repeat
from sklearn.utils import shuffle,resample
import pandas_bokeh as pb
pd.set_option('plotting.backend', 'pandas_bokeh')
pb.output_notebook()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .boolean { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .integer { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .string  { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# ...

# %%
dt.options.display.head_nrows=4

# %%
star_bucks_dt = dt.fread('https://raw.githubusercontent.com/myamullaciencia/open_into_datos/master/starbucks.csv')

# %%
class Hypothesis_Recipe():
    
    def __init__(self,DT,respredict_vars,predict_var,null_type,reps,sample_type,**stats):
        self.DT=DT
        self.respredict_vars=respredict_vars
        self.predict_var=predict_var
        self.null_key = [ stat_key for stat_key in stats.keys()][0]
        if self.null_key=='mean':
            self.mu = stats.get('mean')
        elif self.null_key=='median':
            self.med=stats.get('median')
        elif self.null_key=='prop':
            self.prop = stat.get('prop')
        self.null_type=null_type
        self.reps=reps
        self.sample_type=sample_type
        
    def __repr__(self):
        
        return f' --- Hypothesis Recipe --- \n The response variable: {self.respredict_vars} \n Hypothesis Null type: {self.null_type} \n Point estimate: {self.mu}  \n Sampling type: {self.sample_type}'
        
    def infer_hypothesis(self):
        if self.null_type=='independence':
            X = self.DT[:,f[self.respredict_vars]]
            return X
        elif self.null_type=='point':
            shift = self.mu - self.DT[:,dt.mean(f[self.respredict_vars])].to_list()[0][0]
            X = self.DT[:,f[self.respredict_vars]+shift]
            return X
        else:
            print(f'the given method {self.null_type} is not avail and please specify the correct stat menthod')
    
    def infer_generate(self):
        
        X = self.infer_hypothesis()
        if self.sample_type=="bootstrap":
            rep_size = len(resample(X.to_list()[0]))
            res_var = X.names[0]
            rep_dict={'reps':[],res_var:[]}
            for rep in range(0,self.reps):
                rep_dict['reps'].extend([ v for v in repeat(rep,rep_size)])
                rep_dict[res_var].extend(resample(X.to_list()[0],replace=True,n_samples=rep_size))
            return dt.Frame(rep_dict)
        elif self.sample_type=="permute":
            print(f'The given method {self.sample_type} is not yet implemented')
        else:
            pass
        
    def infer_caluclate(self):
        X= self.infer_generate()
        if self.null_key == 'mean':
            return X[:,{'mean_val':dt.mean(f[1])},by(f[0])]
        elif self.null_key == 'median':
            return X[:,{'median_val':dt.median(f[1])},by(f[0])]
        else:
            print('failed')
            
    def infer_visualization(self):
        X = self.infer_caluclate()[:,f[1]].to_pandas()
        cols = X.shape[0]
        min_v = int(round(X.iloc[:,0].min()))
        max_v = int(round(X.iloc[:,0].max()))
        vis = X.plot_bokeh.hist(title="Null Distribution",fill_color="green",vertical_xlabel=True)
        return vis

# %%
hyp_test_spec = Hypothesis_Recipe(star_bucks_dt,'calories','point',1000,'bootstrap',mean=350)

# %%
hyp_test_spec.infer_visualization()
# Out:
#   <div class="bk-root" id="6b49e6c6-4474-49fe-8653-6fa0a514a061" data-root-id="3490"></div>
# Figure(id='3490', ...)

# %%
test_DT = star_bucks_dt[((f.type == "bistro box") | (f.type=="sandwich")),:][:,f.calories,f.type]

# %%
test_DT[:,{'means':dt.mean(f.calories)},by(f.type)][0,f[1]].to_list()[0]
# Out:
# [377.5]

# %%
ms = test_DT[:,{'means':dt.mean(f.calories)},by(f.type)][:,f[1]].to_list()[0]

# %%
ms
# Out:
# [377.5, 395.7142857142857]

# %%
round([ms[i + 1] - ms[i] for i in range(len(ms)-1)][0],4)
# Out:
# 18.2143
